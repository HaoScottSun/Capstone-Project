# %% [markdown]
# ### 1. Introduction

# %% [markdown]
# This Project aims to give the best recommendation of opening a Chinese restaurant in New York, Manhattan. As we all know, New York city is famous for its centrality of finance, culture and art. New York is also called the center of the universe. Everyday there are a lot of people coming and leaving this city. So it would be a high-return business to open a restaurant in the transportation center of east coast.
# As the core of the city, Manhattan district would be a wonderful choice for a new restaurant’s location. As the people flow in Manhattan is big enough, most of the restaurant will serve a line of waiting people. That means the substitution effect of restaurant is weak. So we can focus on seeking the location with most number of restaurant as our choice.
#
#
# Since we are going to open a Chinese restaurant, we would not like to compete with traditional ones. But we would like to find a similar business surrounding like Chinatown. So we will cluster all the locations and from the cluster having Chinatown in it, we will choose the one with the biggest proportion of restaurant as the final choice.
#
#
# The location with the most restaurant and is similar with Chinatown means the best choice for a new Chinese restaurant. Here we assume that a new launching of a restaurant will not change the situation of the whole market.

# %% [markdown]
# ### 2. Data Description

# %% [markdown]
# #### 1).New York Neighborhood Data

# %% [markdown]
# The data set has a total of 5 boroughs and 306 neighborhoods. In order to segment the neighborhoods and explore them, we will essentially need a dataset that contains the 5 boroughs and the neighborhoods that exist in each borough as well as the latitude and longitude coordinates of each neighborhood.

# %% [markdown]
# #### 2).Neighborhood venues data:

# %% [markdown]
# Next, we are going to start utilizing the Foursquare API to explore the neighborhoods and segment them. we will get the top 100 venues that are in each location within a radius of 1000 meters.

# %% [markdown]
# ### 3. Methodology

# %% [markdown]
# Here we mostly used Pandas to organize and clean our data.
# For clustering, we are using Hierarchical clustering in sklearn to find clusters based on locations' neibourhood venues.
#
# Finally we check all locations which are in the same cluster as 'Chinatown' and group restraurant tyoe venues. Then the one with the highest proportion of restaurant is our choice.

# %% [markdown]
# ### 4. Results

# %% [markdown]
#  After utilize K-means cluster, with k = 8, we have the cluster having Chinatown:
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# And after calculate the aggragated restaurant score, we have the results of:
# ![image.png](attachment:image.png)

# %% [markdown]
# Which indicates Central Harlem has the biggest score of restaurant, and follows by Flatiron and Washington Heights.

# %% [markdown]
# ### 5. Discussion

# %% [markdown]
# As we see from the map:
# ![image.png](attachment:image.png)

# %% [markdown]
# The venues distribution of those 6 locations are similar to Chinatown and Central Harlem, Flatiron and Washington Heights are the top three who have most restaurant in those area. From the map we can see Flatiron would be the best choice because it nears downtown manhattan and locates much closer to chinese living locations.
#
# Here we can prove that data science can help us to make business choice. But we can not make desicions only rely on data. The data in our model and the algorithms have limitations. So the result can be a helpfu, reference but not a golden rule.

# %% [markdown]
# ### 6. Conclusion

# %% [markdown]
# Data Science methods provide us a optional and retional method to make a business choice. Location selection is a tough and subjective business problem in traditional business world. But with the data combining data science method, we can have a simple and direct choice which can most match our selecting strategy. And the choice was made by objective data and machine leanring algorithms, without any subjective preference. Maybe the location is not the best one when we really open a new Chinese restaurant, but it would be a great reference of the selecting strategy and will contribute a lot to the final decision making process.
